# %%
import numpy as np
import pandas as pd
import pyampute
from pyampute.ampute import MultivariateAmputation
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.linear_model import BayesianRidge
import os
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # ivanovo_dataset with deleted  missing values

# %%
X_full = np.genfromtxt(os.path.basename('/Desktop/GIT/Imputations/data_ivanovo.csv') , delimiter=';', skip_header=2)
#colnames = ['discr_1', 'discr_2', 'discr_3', 'discr_4', 'discr_5', 'discr_6', 'cont_1', 'cont_2', 'cont_3', 'cont_4', 'cont_5', 'cont_6', 'cont_7', 'cont_8', 'cont_9', 'cont_10', 'cont_11', 'cont_12'] 
cont_colnames = ['cont_1', 'cont_2', 'cont_3', 'cont_4', 'cont_5', 'cont_6', 'cont_7', 'cont_8', 'cont_9', 'cont_10', 'cont_11', 'cont_12'] 


df = pd.DataFrame(X_full)
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
#df.dropna() 1883/1858
#df

# %%
df_cont = df.iloc[:, 6:18]
df_cont.columns = [str(i) for i in range(df_cont.shape[1])]
df_cont
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.681272  0.839077  1.699830  0.780747  1.965416  2.297007 -0.619881
# 1     1.465668  1.619690  1.556676  2.193946  1.396400 -0.673438  1.092172
# 2    -1.584760 -0.790098 -1.020090 -0.475431 -1.069334 -1.267527 -1.400506
# 3     1.117047  1.467215  1.914561  1.304154  1.111892  0.910800  0.045425
# 4     0.506962  2.299204  1.771407  0.519043  0.732548 -0.574423  1.730865
# ...        ...       ...       ...       ...       ...       ...       ...
# 1878 -0.887519 -0.280463  0.339870 -0.789475 -0.595155 -0.178363  0.453479
# 1879 -0.713209 -0.280463 -0.053802 -0.946497 -1.164170 -1.366541  0.151873
# 1880 -0.364589  0.414796 -0.018014 -0.266068 -0.215811 -1.366541 -0.398112
# 1881 -1.148984 -0.756122 -0.161168 -0.475431 -0.026139  0.019666  0.613152
# 1882 -0.451744  0.092442  0.483024  0.152658  0.258369  0.811785  0.692988
#
#              7         8         9        10        11
# 0    -0.906753  1.710877  1.080780  0.195906 -0.762807
# 1    -0.193068  0.172220  0.592126  1.120988  0.020496
# 2    -1.412281 -0.606606 -2.146019  0.000772  1.699002
# 3     0.936935  0.020254 -0.022903  0.058590 -0.091404
# 4    -1.114912  0.789582  1.266131 -0.136545  1.251401
# ...        ...       ...       ...       ...       ...
# 1878 -0.490437 -0.331168  0.137173 -0.273861  0.468098
# 1879  1.501937 -0.141210  0.389925 -0.729175  0.132397
# 1880 -1.560966 -0.036733 -0.840134 -0.042591  1.475201
# 1881  0.520618  0.457157  0.802753 -0.317224  0.132397
# 1882 -0.312015 -0.293176  0.482600 -0.057045  0.132397
#
# [1858 rows x 12 columns]

# %% [markdown]
# Nonzero values in the column [2]

# %%
# df[(df[[2]] != 0) =='True'].isnull().values.any()
# Out:
# True

# %%
# count = (df[[2]] != 0).sum()
# count
# Out:
# 2    321
# dtype: int64

# %%
# df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## data correlation

# %%
corr = df_cont.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_
{
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_f29cc_row9_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f29cc_row9_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f29cc_row10_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f29cc_row10_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f29cc_row10_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f29cc_row10_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f29cc_row10_col8, #T_f29cc_row11_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f29cc_row11_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f29cc_row11_col3, #T_f29cc_row11_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f29cc_row11_col5, #T_f29cc_row11_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f29cc_row11_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f29cc_row11_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f29cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f29cc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f29cc_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f29cc_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f29cc_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f29cc_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_f29cc_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_f29cc_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_f29cc_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_f29cc_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_f29cc_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_f29cc_level0_col10" class="col_heading

# %%
# corr_pairs_flat_miss, sort_idxs_miss, names = sorted_corr_pairs(X_miss.corr())

# %%
# def sorted_corr_pairs(corr_df):
#     corr_pairs = []
#     indxs = []
#     col_names = []
#     for idx, col in enumerate(df.columns):
#         corr_line = corr_df[df.columns[df.columns != col]].loc[col]
#         corr_pairs.append(corr_line)
#         col_names.append([str(col) + '-' + str(col_i) for col_i in df.columns[df.columns != col]])

    
#     corr_pairs_flat = np.array(corr_pairs).flatten()
    
#     sort_idxs = np.argsort(corr_pairs_flat)
 
#     col_names = np.array(col_names).flatten()
#     return corr_pairs_flat, sort_idxs[::2], col_names

# %%
# corr_pairs_flat_miss, sort_idxs_miss, names = sorted_corr_pairs(df.corr())

# %%
# plt.figure(figsize=(20, 10))
# fig, ax = plt.subplots(1, 1, figsize=(20, 10))
# ax.bar(x=colnames[sort_idxs_miss],height=corr_pairs_flat[sort_idxs])
# ax.bar(x=colnames[sort_idxs_miss],height=corr_pairs_flat_miss[sort_idxs], alpha=0.7)
# # ax.grid(which='major')
# ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
# plt.xticks(rotation=90);
# plt.ylim(-0.8)
# # plt.xticks(col_names[sort_idxs][::2]);
# plt.savefig(f"figures_ivanovo/sorted_correlated_amputed_{p_mech}_{p_miss}.png", dpi=200)

# %% [markdown]
# # la

# %%
def ivanovo_test(param, num, varss):    
    df_ivanovo = df_cont.to_numpy()
    proportion = np.arange(0.1, 1, 0.1)

    df_bias_cc = pd.DataFrame(columns = ['full', 'MCAR', 'MAR', 'MNAR'])

    for pr in proportion:

        n = 0
        df_means = pd.DataFrame(columns = ['mean_full', 'mean_MCAR', 'mean_MAR', 'mean_MNAR'])

        for n in np.arange(100):

            X_full = df_ivanovo
            df_means.loc[n, 'mean_full'] = X_full[:, num].mean() 

            #___MCAR________

            ma = MultivariateAmputation(
                patterns = [ {'incomplete_vars': varss, 'mechanism': "MCAR"} ],
                prop = pr
            )
            X_miss = ma.fit_transform(X_full)

            X_m = pd.DataFrame(X_miss, columns = cont_colnames)
            cc = X_m.dropna()
            df_means.loc[n, 'mean_MCAR'] = cc[param].mean() 


            #___MAR________

            ma = MultivariateAmputation(
                patterns = [ {'incomplete_vars': varss, 'mechanism': "MAR"} ], 
                prop = pr
            )
            X_miss = ma.fit_transform(X_full)

            X_m = pd.DataFrame(X_miss, columns = cont_colnames)
            cc = X_m.dropna()
            df_means.loc[n, 'mean_MAR'] = cc[param].mean() 


            #___MNAR________

            ma = MultivariateAmputation(
                patterns = [ {'incomplete_vars': varss, 'mechanism': "MNAR"} ],
                prop = pr
            )
            X_miss = ma.fit_transform(X_full)
            X_m = pd.DataFrame(X_miss, columns = cont_colnames)
            cc = X_m.dropna()
            df_means.loc[n, 'mean_MNAR'] = cc[param].mean() 


        df_bias_cc.loc[pr, 'full'] = df_means['mean_full'].mean() - df_means['mean_full'].mean() 
        df_bias_cc.loc[pr, 'MCAR'] = df_means['mean_MCAR'].mean() - df_means['mean_full'].mean()
        df_bias_cc.loc[pr, 'MAR'] = df_means['mean_MAR'].mean() - df_means['mean_full'].mean()
        df_bias_cc.loc[pr, 'MNAR'] = df_means['mean_MNAR'].mean() - df_means['mean_full'].mean()


    return df_bias_cc

# %% [markdown]
# ## (000...001)

# %% [markdown]
# CC, analysis by column [11] (very last col without mis values in contin data). we vary ampute proportion
#
# one variable without mis values: cont_12 [11], analysis by it
#
# (for dataset with descrete values same graphic)

# %%
test1_by12 = ivanovo_test(param = 'cont_12', num = 11, varss = np.arange(0, 11, 1))
test1_by12.plot(title = "00..001 by cont_12 (last)")
# Out:
# <AxesSubplot:title={'center':'00..001 by cont_12 (last)'}>

# %% [markdown]
# Потеря по MAR зависит только от 'cont_12', поэтому среднее по переменной 'cont_12' станет меньше относительно исходного. График движется вниз, тк по оси x отложен prop!!, не cor. => очевидно и правильно, что bias растет при увеличении количеcтва потерянных данных.
#
# Кривая MNAR находится выше MAR, тк вклад в wss вносят сразу все 0,1,..,9,10 переменные, а выбиваем в итоге строки с наибольшими суммами. Слишком от многих переменных зависимость => при маленьких cor значения в [11] выбиваются почти случайно, в итоге в среднем отличие среднего от исходного небольшое.

# %% [markdown]
# one variable without mis values: cont_12 [11], analysis by [10]

# %%
test1_by11 = ivanovo_test(param = 'cont_11', num = 10, varss = np.arange(0, 11, 1))
test1_by10 = ivanovo_test(param = 'cont_10', num = 9, varss = np.arange(0, 11, 1))
test1_by9 = ivanovo_test(param = 'cont_9', num = 8, varss = np.arange(0, 11, 1))
test1_by8 = ivanovo_test(param = 'cont_8', num = 7, varss = np.arange(0, 11, 1))

# %%
test1_by3 = ivanovo_test(param = 'cont_3', num = 2, varss = np.arange(0, 11, 1))

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize=(6 * 3,3 * 3))
[ax.set_ylim([-0.7, 0.025]) for ax in axes.flatten()]

test1_by12.plot(ax = axes[0,0],title = "00..001 by cont_12 (last)")
test1_by11.plot(ax = axes[0,1], title = "00..001 by cont_11")
test1_by10.plot(ax = axes[0,2], title = "00..001 by cont_10")
test1_by9.plot(ax = axes[1,0],title = "00..001 by cont_9")
test1_by8.plot(ax = axes[1,1], title = "00..001 by cont_8")
test1_by3.plot(ax = axes[1,2], title = "00..001 by cont_3")
# Out:
# <AxesSubplot:title={'center':'00..001 by cont_3'}>

# %% [markdown]
# Все объясняется корреляцией параметров cont_12 c cont_11, cont_10...

# %%
corr = df_cont.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T
col7 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_df0d6_row6_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_df0d6_row6_col11, #T_df0d6_row9_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_df0d6_row7_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_df0d6_row8_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_df0d6_row8_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_df0d6_row8_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_df0d6_row8_col9, #T_df0d6_row9_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_df0d6_row9_col3, #T_df0d6_row9_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_df0d6_row9_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_df0d6_row9_col6 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_df0d6_row9_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_df0d6_row9_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_df0d6_row10_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_df0d6_row10_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_df0d6_row10_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_df0d6_row10_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_df0d6_row10_col8, #T_df0d6_row11_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_df0d6_row11_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_df0d6_row11_col3, #T_df0d6_row11_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_df0d6_row11_col5, #T_df0d6_row11_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_df0d6_row11_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_df0d6_row11_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_df0d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df0d6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_df0d6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_df0d6_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_df0d6_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_df0d6_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_df0d6_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_df0d6_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_df0d6_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_df0d6_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_df0d6_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_df0d6_level0_col10" class="col_heading

# %% [markdown]
# ## (000010000000)

# %% [markdown]
# Меняем паттерн потери: стб. no.4 lost [ 0,1,2,3,  5,6,7,8,9,10,11]

# %%
test2_by4 = ivanovo_test(param = 'cont_5', num = 4, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])
test2_by11 = ivanovo_test(param = 'cont_12', num = 11, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])
test2_by10 = ivanovo_test(param = 'cont_11', num = 10, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])

# %%
test2_by9 = ivanovo_test(param = 'cont_10', num = 9, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])
test2_by8 = ivanovo_test(param = 'cont_9', num = 8, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])
test2_by7 = ivanovo_test(param = 'cont_8', num = 7, varss = [ 0,1,2,3,  5,6,7,8,9,10,11])

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize=(6 * 3,3 * 3))
[ax.set_ylim([-0.5, 0.15]) for ax in axes.flatten()]

test2_by4.plot(ax = axes[0,0], title = "000010.. by [4]")
test2_by11.plot(ax = axes[0,1],title = "000010.. by [11]")
test2_by10.plot(ax = axes[0,2], title = "000010.. by [10]")
test2_by9.plot(ax = axes[1,0], title = "000010.. by [9]")
test2_by8.plot(ax = axes[1,1],title = "000010.. by [8]")
test2_by7.plot(ax = axes[1,2], title = "000010.. by [7]")
# Out:
# <AxesSubplot:title={'center':'000010.. by [7]'}>

# %%
corr = df_cont.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_bf4a1_row0_col0, #T_bf4a1_row1_col1, #T_bf4a1_row2_col2, #T_bf4a1_row3_col3, #T_bf4a1_row4_col4, #T_bf4a1_row5_col5, #T_bf4a1_row6_col6, #T_bf4a1_row7_col7, #T_bf4a1_row8_col8, #T_bf4a1_row9_col9, #T_bf4a1_row10_col10, #T_bf4a1_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bf4a1_row0_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bf4a1_row0_col2, #T_bf4a1_row4_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_bf4a1_row0_col3 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_bf4a1_row0_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_bf4a1_row0_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_bf4a1_row0_col6, #T_bf4a1_row9_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_bf4a1_row0_col7, #T_bf4a1_row6_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_bf4a1_row0_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_bf4a1_row0_col9, #T_bf4a1_row4_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_bf4a1_row0_col10, #T_bf4a1_row6_col3, #T_bf4a1_row6_col4, #T_bf4a1_row10_col4, #T_bf4a1_row10_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_bf4a1_row0_col11, #T_bf4a1_row10_col0, #T_bf4a1_row10_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_bf4a1_row1_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_bf4a1_row1_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_bf4a1_row1_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_bf4a1_row1_col4, #T_bf4a1_row8_col11 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_bf4a1_row1_col5, #T_bf4a1_row1_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_bf4a1_row1_col7, #T_bf4a1_row10_col9 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_bf4a1_row1_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_bf4a1_row1_col9, #T_bf4a1_row2_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_bf4a1_row1_col10, #T_bf4a1_row4_col10, #T_bf4a1_row8_col3, #T_bf4a1_row9_col1, #T_bf4a1_row10_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_bf4a1_row1_col11 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bf4a1_row2_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_bf4a1_row2_col1 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_bf4a1_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_bf4a1_row2_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_bf4a1_row2_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_bf4a1_row2_col6, #T_bf4a1_row3_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_bf4a1_row2_col7, #T_bf4a1_row5_col9, #T_bf4a1_row7_col1, #T_bf4a1_row7_col2, #T_bf4a1_row7_col3, #T_bf4a1_row7_col4, #T_bf4a1_row7_col5, #T_bf4a1_row7_col6, #T_bf4a1_row7_col8, #T_bf4a1_row7_col10, #T_bf4a1_row7_col11, #T_bf4a1_row8_col7, #T_bf4a1_row11_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bf4a1_row2_col8, #T_bf4a1_row8_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_bf4a1_row2_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_bf4a1_row2_col11, #T_bf4a1_row11_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_bf4a1_row3_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_bf4a1_row3_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_bf4a1_row3_col2 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_bf4a1_row3_col4, #T_bf4a1_row4_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_bf4a1_row3_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_bf4a1_row3_col6, #T_bf4a1_row5_col7, #T_bf4a1_row6_col10, #T_bf4a1_row11_col10 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_bf4a1_row3_col8, #T_bf4a1_row4_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_bf4a1_row3_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_bf4a1_row3_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_bf4a1_row3_col11, #T_bf4a1_row8_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_bf4a1_row4_col0, #T_bf4a1_row6_col8, #T_bf4a1_row8_col10, #T_bf4a1_row9_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_bf4a1_row4_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_bf4a1_row4_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_bf4a1_row4_col7, #T_bf4a1_row7_col9, #T_bf4a1_row8_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_bf4a1_row4_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_bf4a1_row4_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_bf4a1_row5_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_bf4a1_row5_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_bf4a1_row5_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bf4a1_row5_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bf4a1_row5_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_bf4a1_row5_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_bf4a1_row5_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_bf4a1_row5_col10 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_bf4a1_row5_col11 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_bf4a1_row6_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_bf4a1_row6_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_bf4a1_row6_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_bf4a1_row6_col7 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_bf4a1_row6_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_bf4a1_row6_col11, #T_bf4a1_row9_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_bf4a1_row7_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_bf4a1_row8_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_bf4a1_row8_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_bf4a1_row8_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_bf4a1_row8_col9, #T_bf4a1_row9_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_bf4a1_row9_col3, #T_bf4a1_row9_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_bf4a1_row9_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_bf4a1_row9_col6 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_bf4a1_row9_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_bf4a1_row9_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_bf4a1_row10_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_bf4a1_row10_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_bf4a1_row10_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_bf4a1_row10_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_bf4a1_row10_col8, #T_bf4a1_row11_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_bf4a1_row11_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_bf4a1_row11_col3, #T_bf4a1_row11_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_bf4a1_row11_col5, #T_bf4a1_row11_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_bf4a1_row11_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_bf4a1_row11_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bf4a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf4a1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bf4a1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bf4a1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bf4a1_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_bf4a1_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_bf4a1_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_bf4a1_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_bf4a1_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_bf4a1_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_bf4a1_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_bf4a1_level0_col10" class="col_heading
